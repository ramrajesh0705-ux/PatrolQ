# %%
# !npm install -g localtunnel
# Out:
# ⠙⠹⠸
# changed 22 packages in 475ms
# ⠸
# ⠸3 packages are looking for funding
# ⠸  run `npm fund` for details
# ⠸

# %%
import os
os.chdir('/content/drive/MyDrive/PatrolQ')

# %%
# !mlflow ui --port 5000 & npx localtunnel --port 5000

# %%
# !curl ipv4.icanhazip.com
# Out:
# 35.233.132.24

# %%
import subprocess
import time

print("Starting Streamlit app with localtunnel...")

# Start localtunnel and capture its output for the URL
st_tunnel = subprocess.Popen('npx localtunnel --port 8501', shell=True, stdout=subprocess.PIPE)
time.sleep(4) # Give localtunnel some time to establish the connection and print the URL
streamlit_link = st_tunnel.stdout.readline().decode('utf-8').strip()
print(f"Streamlit Link: {streamlit_link}")

# Start the Streamlit app in the background
subprocess.Popen("streamlit run app/Home.py --server.port 8501", shell=True)

print("\n✅ Streamlit app and localtunnel should be running.")
print("Access your Streamlit app at the link above.")
# Out:
# Starting Streamlit app with localtunnel...
# Streamlit Link: your url is: https://metal-hotels-smash.loca.lt
#
# ✅ Streamlit app and localtunnel should be running.
# Access your Streamlit app at the link above.

# %%
# !ps aux | grep -E "streamlit"
# Out:
# root        7319  0.0  0.0   7372  3500 ?        S    17:40   0:00 /bin/bash -c ps aux | grep -E "streamlit"
# root        7321  0.0  0.0   6480  2584 ?        S    17:40   0:00 grep -E streamlit

# %%
# !fuser -k 8501/tcp
# !fuser -k 5000/tcp

# %%
import subprocess
import time
import os

# 1. Verify the DB exists before starting
db_path = "/content/drive/MyDrive/PatrolQ/mlflow.db"
if not os.path.exists(db_path):
    print(f"⚠️ Warning: Could not find DB at {db_path}")
    print("Check if Drive is mounted and the path is correct.")

# 2. Get Bypass IP
print("Bypass IP:")
# !curl -s ipv4.icanhazip.com

# 3. Start Tunnels
print("\nStarting Tunnels...")
mlflow_tunnel = subprocess.Popen('npx localtunnel --port 5000', shell=True, stdout=subprocess.PIPE)
time.sleep(4)
print(f"MLflow Link: {mlflow_tunnel.stdout.readline().decode('utf-8').strip()}")

st_tunnel = subprocess.Popen('npx localtunnel --port 8501', shell=True, stdout=subprocess.PIPE)
time.sleep(4)
print(f"Streamlit Link: {st_tunnel.stdout.readline().decode('utf-8').strip()}")

# 4. Start Servers
# We use sqlite:/// to tell MLflow to use your specific database file
subprocess.Popen(f"mlflow ui --backend-store-uri sqlite:///{db_path} --port 5000", shell=True)

# Start Streamlit and capture stderr for debugging
streamlit_process = subprocess.Popen(
    "streamlit run app/Home.py --server.port 8501",
    shell=True,
    stderr=subprocess.PIPE,
    stdout=subprocess.PIPE
)

# Give Streamlit a moment to start and produce output
time.sleep(5)

# Read any error output from Streamlit
stderr_output = streamlit_process.stderr.read().decode('utf-8')
if stderr_output:
    print("\nStreamlit Error Output:")
    print(stderr_output)

print("\n✅ Systems Online. Give it 15 seconds to load your DB data.")
# Out:
# Bypass IP:
# 35.233.132.24
#
# Starting Tunnels...
# MLflow Link: your url is: https://bright-cougars-juggle.loca.lt
# Streamlit Link: your url is: https://honest-experts-greet.loca.lt

# %%
# !pgrep -a streamlit

# %%
# !pkill -f streamlit
# !pkill -f mlflow

# %%
import pandas as pd

# %%
df = pd.read_csv("C:\Dev\AIML\PatrolQ\data\processed\crime_cleaned.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Date', 'Block', 'Primary Type',
#        'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat',
#        'District', 'Ward', 'Community Area', 'Year', 'Latitude', 'Longitude',
#        'month', 'hour', 'day_num'],
#       dtype='object')

# %%
df.drop(['Unnamed: 0.1','Unnamed: 0'],axis=1,inplace=True)

# %%
df.drop(['X Coordinate','Y Coordinate','Location'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Block', 'Primary Type', 'Description',
#        'Location Description', 'Arrest', 'Domestic', 'Beat', 'District',
#        'Ward', 'Community Area', 'Year', 'Latitude', 'Longitude', 'month',
#        'hour', 'day_num'],
#       dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0                 Date                    Block  \
# 0           0  2018-03-11 07:35:00      053XX W AGATITE AVE
# 1           1  2019-02-03 20:00:00      109XX S WESTERN AVE
# 2           2  2024-01-06 15:40:00    072XX S LAFAYETTE AVE
# 3           3  2019-06-22 00:00:00  016XX S SPRINGFIELD AVE
# 4           4  2017-03-07 19:31:00    041XX N CLARENDON AVE
#
#          Primary Type                          Description  \
# 0             BATTERY                               SIMPLE
# 1       OTHER OFFENSE              HARASSMENT BY TELEPHONE
# 2  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 3     CRIMINAL DAMAGE                           TO VEHICLE
# 4       OTHER OFFENSE       HARASSMENT BY ELECTRONIC MEANS
#
#   Location Description  Arrest  Domestic  Beat  District  Ward  \
# 0            APARTMENT   False      True  1623      16.0  45.0
# 1            APARTMENT   False      True  2212      22.0  19.0
# ...

# %%
df.to_csv("C:\Dev\AIML\PatrolQ\data\processed\crime_cleaned.csv",index=False)
